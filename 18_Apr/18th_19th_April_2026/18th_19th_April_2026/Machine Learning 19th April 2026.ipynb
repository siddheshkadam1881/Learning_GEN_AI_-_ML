# %% [markdown]
# # Raw dataset
# ### Machine Learning Algorithm - Supervised Machine Learning
#
# ### EDA - Exploratory Data Analytics - Uni-variate analysis, Bi-variate analysis and Multivariate analysis
#
# ### Data Preprocessing
# 1. Handling Missing data - Center tendancy method (uni-variate method) mean/median/mode, knn imputation, sklearnlearn
# 2. Encoding method - Text to Vector (Label encoder or One Hot Encoder method) Char to Number
# 3. Outlier Treatement - Transformation method (capping method)
# 4. Feature Scalling - Standarisation and Normalization
# 5. Balance Data set - Undersampling or Oversampling, SMOTE - This is only applicable in Classification Problem
